# %% [markdown]
# # Import Libraries
#
# **Import the usual libraries for pandas and plotting. You can import sklearn later on.**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## Get the Data
#
# ** Use pandas to read loan_data.csv as a dataframe called loans.**

# %%
df = pd.read_csv('loan_data.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9578 entries, 0 to 9577
# Data columns (total 14 columns):
# credit.policy        9578 non-null int64
# purpose              9578 non-null object
# int.rate             9578 non-null float64
# installment          9578 non-null float64
# log.annual.inc       9578 non-null float64
# dti                  9578 non-null float64
# fico                 9578 non-null int64
# days.with.cr.line    9578 non-null float64
# revol.bal            9578 non-null int64
# revol.util           9578 non-null float64
# inq.last.6mths       9578 non-null int64
# delinq.2yrs          9578 non-null int64
# pub.rec              9578 non-null int64
# not.fully.paid       9578 non-null int64
# dtypes: float64(6), int64(7), object(1)
# memory usage: 1.0+ MB

# %%
df.describe()
# Out:
#        credit.policy     int.rate  installment  log.annual.inc          dti  \
# count    9578.000000  9578.000000  9578.000000     9578.000000  9578.000000
# mean        0.804970     0.122640   319.089413       10.932117    12.606679
# std         0.396245     0.026847   207.071301        0.614813     6.883970
# min         0.000000     0.060000    15.670000        7.547502     0.000000
# 25%         1.000000     0.103900   163.770000       10.558414     7.212500
# 50%         1.000000     0.122100   268.950000       10.928884    12.665000
# 75%         1.000000     0.140700   432.762500       11.291293    17.950000
# max         1.000000     0.216400   940.140000       14.528354    29.960000
#
#               fico  days.with.cr.line     revol.bal   revol.util  \
# count  9578.000000        9578.000000  9.578000e+03  9578.000000
# mean    710.846314        4560.767197  1.691396e+04    46.799236
# std      37.970537        2496.930377  3.375619e+04    29.014417
# ...

# %%
sns.set_style=('whitegrid')

# %%
##강사님 답변
plt.figure(figsize=(10,6))
df[df['credit.policy'] ==1]['fico'].hist(alpha=0.5, color='blue',bins=30
                                        ,label='Credit.Policy=0')
df[df['credit.policy']==0]['fico'].hist(alpha=0.5, color='red'
                                       ,bins=30,label='Credit Policy=0')
plt.legend()
plt.xlabel('F100')
# Out:
# Text(0.5, 0, 'F100')

# %%
##강사님 답변
plt.figure(figsize=(10,6))
df[df['not.fully.paid'] ==1]['fico'].hist(alpha=0.5, color='blue',bins=30
                                        ,label='Not.fully.paid=0')
df[df['not.fully.paid']==0]['fico'].hist(alpha=0.5, color='red'
                                       ,bins=30,label='Not.fully.paid=0')
## df[df~ ] boolean 값으로 df 구해서 그림
plt.legend()

plt.xlabel('F100')
# Out:
# Text(0.5, 0, 'F100')

# %%
df.groupby('credit.policy')['fico'].hist(bins=30,alpha=0.45)
# Out:
# credit.policy
# 0    AxesSubplot(0.125,0.125;0.775x0.755)
# 1    AxesSubplot(0.125,0.125;0.775x0.755)
# Name: fico, dtype: object

# %%
df.groupby('not.fully.paid')['fico'].hist(bins=30,alpha=0.45)
# Out:
# not.fully.paid
# 0    AxesSubplot(0.125,0.125;0.775x0.755)
# 1    AxesSubplot(0.125,0.125;0.775x0.755)
# Name: fico, dtype: object

# %%
df.head(5)
# Out:
#    credit.policy             purpose  int.rate  installment  log.annual.inc  \
# 0              1  debt_consolidation    0.1189       829.10       11.350407
# 1              1         credit_card    0.1071       228.22       11.082143
# 2              1  debt_consolidation    0.1357       366.86       10.373491
# 3              1  debt_consolidation    0.1008       162.34       11.350407
# 4              1         credit_card    0.1426       102.92       11.299732
#
#      dti  fico  days.with.cr.line  revol.bal  revol.util  inq.last.6mths  \
# 0  19.48   737        5639.958333      28854        52.1               0
# 1  14.29   707        2760.000000      33623        76.7               0
# 2  11.63   682        4710.000000       3511        25.6               1
# 3   8.10   712        2699.958333      33667        73.2               1
# 4  14.97   667        4066.000000       4740        39.5               0
#
#    delinq.2yrs  pub.rec  not.fully.paid
# ...

# %%
##강사님 답변
plt.figure(figsize =(11,7))
sns.countplot(x='purpose',hue='not.fully.paid',data=df, palette='Set1')

# %%
sns.countplot(df['purpose'],hue='not.fully.paid', data=df)

# %%
## 강사님 답변
sns.jointplot(x='fico',y='int.rate',data=df,color='purple')

# %%
sns.jointplot('fico','int.rate', data=df , color='m')

# %%
##강사님답변
print('아래와 동일')
# Out:
# 아래와 동일

# %%
sns.lmplot(x='fico',y='int.rate', data=df,hue='credit.policy',col='not.fully.paid',size=8,palette='Set1')
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\seaborn\regression.py:546: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# # Setting up the Data
#
# Let's get ready to set up our data for our Random Forest Classification Model!
#
# **Check loans.info() again.**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9578 entries, 0 to 9577
# Data columns (total 14 columns):
# credit.policy        9578 non-null int64
# purpose              9578 non-null object
# int.rate             9578 non-null float64
# installment          9578 non-null float64
# log.annual.inc       9578 non-null float64
# dti                  9578 non-null float64
# fico                 9578 non-null int64
# days.with.cr.line    9578 non-null float64
# revol.bal            9578 non-null int64
# revol.util           9578 non-null float64
# inq.last.6mths       9578 non-null int64
# delinq.2yrs          9578 non-null int64
# pub.rec              9578 non-null int64
# not.fully.paid       9578 non-null int64
# dtypes: float64(6), int64(7), object(1)
# memory usage: 1.0+ MB

# %% [markdown]
# ## Categorical Features
#
# Notice that the **purpose** column as categorical
#
# That means we need to transform them using dummy variables so sklearn will be able to understand them. Let's do this in one clean step using pd.get_dummies.
#
# Let's show you a way of dealing with these columns that can be expanded to multiple categorical features if necessary.
#
# **Create a list of 1 element containing the string 'purpose'. Call this list cat_feats.**

# %%
cat_feats = df['purpose']
cat_feats.head()
# Out:
# 0    debt_consolidation
# 1           credit_card
# 2    debt_consolidation
# 3    debt_consolidation
# 4           credit_card
# Name: purpose, dtype: object

# %%
## 강사님
final_df = pd.get_dummies(df,columns=cat_feats,drop_first=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-5-6541399921e6> in <module>
#       1 ## 강사님
# ----> 2 final_df = pd.get_dummies(df,columns=cat_feats,drop_first=True)
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\reshape.py in get_dummies(data, prefix, prefix_sep, dummy_na, columns, sparse, drop_first, dtype)
#     810                 include=dtypes_to_encode)
#     811         else:
# --> 812             data_to_encode = data[columns]
#     813
#     814         # validate prefixes and separator to avoid silently dropping cols
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2932                 key = list(key)
#    2933             indexer = self.loc._convert_to_indexer(key, axis=1,
# -> 2934                                                    raise_missing=True)
#    2935
# ...

# %%
final_df = df.rename(index=cat_feats)
pd.get_dummies(final_df)
del final_df['purpose']
final_df.head()
# Out:
#                     credit.policy  int.rate  installment  log.annual.inc  \
# debt_consolidation              1    0.1189       829.10       11.350407
# credit_card                     1    0.1071       228.22       11.082143
# debt_consolidation              1    0.1357       366.86       10.373491
# debt_consolidation              1    0.1008       162.34       11.350407
# credit_card                     1    0.1426       102.92       11.299732
#
#                       dti  fico  days.with.cr.line  revol.bal  revol.util  \
# debt_consolidation  19.48   737        5639.958333      28854        52.1
# credit_card         14.29   707        2760.000000      33623        76.7
# debt_consolidation  11.63   682        4710.000000       3511        25.6
# debt_consolidation   8.10   712        2699.958333      33667        73.2
# credit_card         14.97   667        4066.000000       4740        39.5
#
#                     inq.last.6mths  delinq.2yrs  pub.rec  not.fully.paid
# ...

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split

# %%
dtree = DecisionTreeClassifier()

# %%
## 강사님답변

# %%
x = final_df.drop('not.fully.paid',axis=1)
y= final_df['not.fully.paid']

# %%
x_train,x_test, y_train,y_test = train_test_split(x,y,test_size=0.33)

# %%
dtree.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
predictions = dtree.predict(x_test)

# %% [markdown]
# ## Predictions and Evaluation of Decision Tree
# Create predictions from the test set and create a classification report and a confusion matrix.

# %%
from sklearn.metrics import classification_report, confusion_matrix

# %%
print(confusion_matrix(y_test,predictions))
print(classification_report(y_test,predictions))
# Out:
# [[2292  391]
#  [ 362  116]]
#               precision    recall  f1-score   support
#
#            0       0.86      0.85      0.86      2683
#            1       0.23      0.24      0.24       478
#
#    micro avg       0.76      0.76      0.76      3161
#    macro avg       0.55      0.55      0.55      3161
# weighted avg       0.77      0.76      0.76      3161

# %% [markdown]
# ## Training the Random Forest model
# Now its time to train our model!
#
# Create an instance of the RandomForestClassifier class and fit it to our training data from the previous step.

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc = RandomForestClassifier(n_estimators=600)

# %%
rfc.fit(x_train,y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=600, n_jobs=None,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
rfcPred = rfc.predict(x_test)

# %%
print(classification_report(y_test,rfcPred))
print(confusion_matrix(y_test,rfcPred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      1.00      0.92      2683
#            1       0.57      0.02      0.03       478
#
#    micro avg       0.85      0.85      0.85      3161
#    macro avg       0.71      0.51      0.48      3161
# weighted avg       0.81      0.85      0.78      3161
#
# [[2677    6]
#  [ 470    8]]
